# %%
import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


# import case UUIDs

file = r'C:\Users\tanma\Downloads\metadata.cart.2021-02-18.json'

result = []
readfile = pd.read_json(file)
readfile = readfile['associated_entities']
result.append(readfile)
data_frame = pd.concat(result)

case_UUID = [d[0]['case_id'] for d in data_frame]

case_uuid = []
for uid in case_UUID:
    case_uuid.append(uid.upper())
case_uuid
# Out:
# 56-4CA9-B1F1-0D929697B280',
#  '6439621E-DA61-4723-91CC-C5D87D0A4ABC',
#  'E1119732-3E97-4259-BC69-DC4269D9496D',
#  '67C5F371-3FA9-47C5-8B15-C2DD9ACC8519',
#  '94B95984-B2FB-4E42-8887-45E7086C3179',
#  '848773A3-2F4A-4186-AB3F-DE667129ACCF',
#  '31427699-E27A-4035-8925-6D8D6900D097',
#  'CEA9D8F9-E18C-4947-A461-5F712E3C1E6D',
#  '2399CAEB-EAD2-4003-AF38-809DB4AC2E2B',
#  '327A2395-85C8-42E1-9638-8E037A1723ED',
#  '125B0A9A-6CBE-4207-9178-E7FF03487E87',
#  '6D24E675-2FA4-4102-861F-7516650B3049',
#  'EE5744C0-A8DC-43F2-ABDD-0B5529A3E9FB',
#  'D7CE6B79-F7C0-481E-9DBD-6273F01C9786',
#  'C4699748-F01D-4B30-9C74-1CA77FB84AC1',
#  'D6F911B5-E895-43F8-8F86-0AC2F1BC6FAE',
#  '0BC5744C-5FA3-45BB-87D0-70A02068B392',
#  '4CFEF7F9-F1EE-401C-A2A3-C225D4ADC3B6',
#  'DD3BFB26-B534-4917-9C4D-9FE7B6477762',
#  '86CF879E-3B40-44DD-AAA7-6F49F54A15D9',
#  '1783CAC1-253A-40AF-A9AC-48DFB20E1AB8',
#  '7ACF33E7-C386-45FD-8C9A-469600378687',
#  '6644FD4E-D2FE-4785-A73C-0F36FCC740E2',
#  '2C90D5E3-AC8C-4C86-A06F-42CCC064EB49',
#  '623BEFD6-0CA4-4A6C-9CF5-D9385C3B718F',
#  '03565036-B6D3-432F-8D9A-7099818E0788',
#  '9416FF9B-6F29-4554-B04D-B537A3AE3969',
#  '56BBD282-B88D-4730-9242-AB97D08DC83A',
#  'F72C1D69-DA35-459F-8542-59BFD6C09C23',
#  '2021ED1F-DC75-4701-B8B8-1386466E4802',
#  'F6581EEE-61B9-43D4-AB0D-CE5CE3BA1C74',
#  '96B9C7DB-1BE1-4B60-B47C-26B654C3D64C',
#  '5D688049-F271-40EF-813A-D37240FFE21C',
#  'A68A3361-48B4-4BD0-999D-B4CC3D43EB4A',
#  '8240C4AE-F878-4882-AA07-7857C7AC52CF',
#  '55262FCB-1B01-4480-B322-36570430C917',
#  '34AB0CB8-BF19-4CBB-B4EB-3C45EE5AA60B',
#  '86A18AE0-DFB1-49C3-B5C4-67EC331D6E40',
#  '5EA18514-51AD-4844-ABEA-15E82F0B10C9',
#  '2B36853F-34D3-47C5-BA6A-E5A93233D2B1',
#  '6DD0DD7B-62FF-4FD1-A99A-B265F1A91DCA',
#  '1133B8A9-6B11-4511-B70A-F200E3B8B5DB',
#  '69A68FBC-E43D-4652-85EE-693211BDED47',
#  '70AB4F23-23C4-409F-A5CC-18A010C3A24E',
#  'C5F00132-1C6B-4337-AF6F-596C652665CC',
#  'C1E704D6-A33B-4891-90BD-992B0040C075',
#  '5CD79093-1571-4F71-8136-0D84CCABDCAC',
#  'AC075BC0-1B59-4557-BEEA-541694FAEE03',
#  'F7AB565C-83B5-4988-B9BE-8A46F65DCA8C',
#  'C0427237-B476-4AF4-B664-7BD479922EA5',
#  'A272171B-44F5-47A5-89BE-7520413C01AD',
#  '074E8B06-3929-4896-9263-3B80AD6A355B',
#  'F63722C1-A0BB-4BF9-8A10-1D76A8E1A0BA',
#  'B7A4DF9A-4E25-4550-9C10-338CA1921C2F',
#  '9D95A65B-E41D-4F93-92D4-99DCE29FF40D',
#  '6020D1B4-EE20-4CC9-82A3-340B5E3122F1',
#  '632984BD-DC81-42B6-B024-476CFD0BB2AE',
#  'D3D545B3-457F-4389-821F-704CB24AFF7F',
#  'C462E422-EB8D-4DAF-9897-2A9C6CBD783A',
#  '4CF0F639-7940-48B6-8EA1-2A3494097CDB',
#  'BC0BC70F-C6CF-4DBC-9DC3-8B7BC5F381A4',
#  'DE531604-BD1A-49DF-96C2-6DE3AE703F1D',
#  'BA39BFBC-5CAC-4F6C-B55C-4EEE3466EE93',
#  'C07B122E-AC50-4DB2-ADD2-5617A5D0E976',
#  '2B19A6B4-7A17-4452-B4AA-6FC18ADC0C3C',
#  'EDA6D2D5-4199-4F76-A45B-1D0401B4E54C',
#  'CCB22ECC-6E18-44B8-AD48-6AB51314B16E',
#  'C31900A4-5DCD-4022-97AC-638E86E889E4',
#  '7F0BBBA1-9BC3-45DB-BDDA-EB3319BB15D2',
#  '34D5A193-85E5-4399-8A9B-E92858EAFDFE',
#  '9DDC3E7B-8B54-4A83-8335-8053940F56C1',
#  'A412B374-4D25-491F-B76F-DDAA989ACF59',
#  'D67CD793-2931-429A-9084-2F3C4C8BE7AD',
#  '96E1FC6D-693F-4F4F-B5F7-8D6E1C6C43F8',
#  '478EB8AA-50B8-4CE5-98E4-D518EDE4B174',
#  '95873E61-AFDB-496C-9F77-3F9BEB008CDA',
#  'DDDD8E2F-E540-418A-B02E-698D18A12C14',
#  '4842BAC3-ABAA-4900-871F-F2C3BA6457F5',
#  'CB9F5E50-F49D-4899-8895-9367AFCC1015',
#  '1D75E89D-4B01-443C-BE54-749C7A667BF4',
#  '43D5632E-7272-4AAD-9496-7F5A99671223',
#  '161917B8-88AD-407B-ADE6-D6B98478B359',
#  '9B13927C-7357-44FD-8385-92AE6A656B7D',
#  '69054195-9E93-49E5-B820-69B0091CC2D4',
#  'DBCAD60F-86C7-41E3-B0AE-BAA39C9F83DD',
#  '24334AC1-28A3-4B61-B590-3F51E375B247',
#  '2E32F31F-9817-4935-B259-96C59936EE33',
#  'EADB0562-2165-4ADB-AD58-018E73F82780',
#  '993103B1-E5A1-4C33-8629-BE53EBC41D64',
#  '3EFA245D-177D-4EF9-94F7-F554C54E345E',
#  'DD43FFD9-DA18-4AD3-ABE7-6F443C76A717',
#  'B26D41CD-393B-4CD4-8925-A9488F7DE576',
#  'CD7FB75E-1C2E-4201-86D3-B3BA21F476BF',
#  'FA4E082A-D213-412E-8D91-842A6F4BEF12',
#  '96312510-C126-485D-8109-ED81844A1DC3',
#  '4D0FEC97-E024-4608-A0CC-426A3DECC7B1',
#  'D8ECBA6A-9FFF-4993-A799-9A8D2AEA524E',
#  '955D4263-61F7-42E8-8A6E-772A0D6C209D',
#  '5362CBC4-CD28-4AFD-A8AC-1A4C2C33CAD2',
#  '955D4263-61F7-42E8-8A6E-772A0D6C209D',
#  'FF0F875F-113A-4C0F-8C0A-4259CD496E6D',
#  'F43D622F-EED5-4933-ADC6-AE9AD1E33028',
#  'B7F74AE1-6F58-447C-BE50-A7666EB19D9A',
#  '9676E46B-8F29-43CD-AB65-EB6A535CCED4',
#  '2C86C3EA-D926-4D39-A5AE-39ECE4774287',
#  '6CB6F179-DEFD-4661-AF0A-C353B74C0C49',
#  '077506EA-8F11-405D-BB8E-3C9924FE54D0',
#  '8C7E74E0-71EF-49B8-9217-94B8EF740EF9',
#  '0A229F95-0EA1-4D63-953E-74F5EC2F3028',
#  '3927F736-3B5C-48C8-9D9E-83669EC44770',
#  '451E1A67-47E6-4738-99D7-FB7771EF61A3',
#  '9857BE0C-AECA-4A43-90B1-0535BD08E086',
#  'AA60FA8D-C374-40E0-AF2D-B007701E67E3',
#  'CAA9B533-24B4-4ECD-9159-C165DE049F6A',
#  '3CA67CD0-81DA-4F68-A9FA-F1A8C013C28D',
#  '7032EC9C-E96B-4642-A7B6-D0AEE7A3ADD2',
#  'E8614B7D-132E-4B4E-B1AE-DF8BB4F2D4D4',
#  'B379BFB8-284E-4300-8325-85CFD6809CB8',
#  '4D26DADA-5EB7-4D4E-8EB8-F5465C5C3428',
#  '9495F029-9882-4C9B-A557-B3AEC9E91698',
#  '5CDAE21D-EEE5-478F-932A-0F51FCF5F031',
#  '71FC8941-4CFB-47EA-A533-873D38F8C95C',
#  'FA176764-A76F-44C7-B97A-CD6D21E052BE',
#  '8577FFCB-242E-40E2-98D4-2831D952BE34',
#  '738E1ACC-1F0C-4A96-9C8A-222727EF5AF8',
#  '3AFA1E93-1DF8-4E4C-AAA4-557463F4BB77',
#  '8CF8B620-7AB6-4B6E-84BC-FF5A83F381FA',
#  '9C895825-D6F6-4D14-A662-23212200F6E5',
#  'D3D4D709-AB34-4617-AA8C-51A3D0A3EFE6',
#  'CD781589-3820-45A2-906B-8D60CD02F3EF',
#  '7EB18190-5A41-4637-9783-F81BBDE499E4',
#  '4649DEE3-B668-44CD-AB97-3834DE3EF8F8',
#  '56230E4A-29CA-4F37-A0F9-730DBDFB6FA2',
#  'F130F376-5801-40F9-975D-A7E2F7B5670D',
#  '6BC4C56D-AAC5-49A2-9913-9538D06D898F',
#  'E112B452-8850-4353-BFED-0DBDC243290B',
#  'F39EDD06-1016-4E8E-A42E-12F7E699DDC5',
#  'CB0A2055-2168-4454-8755-47DD613DB36F',
#  'DBA9BEEC-5E51-48C0-9229-0EE286A02A1A',
#  'C1442467-D618-435F-8792-B1A18F696F1A',
#  '77E25AE8-82EC-4DEA-8E62-1176F27E47BA',
#  '57AF5C72-0D60-4A6B-B1B4-EC6DAB90F80F',
#  '42621DFA-ABFD-4C7D-8BC5-A02A09D1C2B4',
#  '21EF1730-E5A7-47CE-B419-D000BB59AE15',
#  '59BE60A3-E0F6-4D63-B98C-574EF92428C4',
#  '96B9C7DB-1BE1-4B60-B47C-26B654C3D64C',
#  '91DA548B-5C64-49C3-A44A-1EF115F53311',
#  'F30EB65F-FB44-4062-AC39-A38D072F655F',
#  'C8F39325-5382-447C-9291-A6915FC978B8',
#  '4229E432-6AC5-49D2-B58A-E8713DDB79BD',
#  'BFA3DBC0-361C-400E-8C10-0ACA7049FCE9',
#  '0A2A3529-F645-4967-9A58-89EE20B8BB62',
#  '14D1D84E-99E1-41AD-8892-3B4DA3D4F948',
#  ...]

# %%
# data import
path = r'C:\Users\tanma\Downloads\data'
all_files = glob.glob(path + "/*.txt")

result = []
for file in all_files:
    readfile = pd.read_csv(file , sep = "\t")
    pivoted_file = readfile.pivot_table(columns = "miRNA_ID" , values = "reads_per_million_miRNA_mapped")
    result.append(pivoted_file)

miRNA_data = pd.concat(result)
miRNA_data['bcr_patient_uuid'] = case_uuid
miRNA_data
# Out:
# miRNA_ID                        hsa-let-7a-1  hsa-let-7a-2  hsa-let-7a-3  \
# reads_per_million_miRNA_mapped   6540.401419   6668.261153   6475.719437
# reads_per_million_miRNA_mapped   6888.809148   6960.156629   7004.224191
# reads_per_million_miRNA_mapped   6982.726550   6935.993741   6930.185144
# reads_per_million_miRNA_mapped   7884.689914   7942.056819   7980.192772
# reads_per_million_miRNA_mapped   9625.744708   9806.970148   9788.154392
# ...                                      ...           ...           ...
# reads_per_million_miRNA_mapped   4178.677650   4138.763325   4207.439443
# reads_per_million_miRNA_mapped  10979.201793  10964.916514  11015.108033
# reads_per_million_miRNA_mapped   9472.598875   9337.818656   9335.980744
# reads_per_million_miRNA_mapped  11086.578367  11054.688802  11162.969189
# reads_per_million_miRNA_mapped   7252.007111   7235.012007   7305.280226
#
# miRNA_ID                          hsa-let-7b   hsa-let-7c   hsa-let-7d  \
# reads_per_million_miRNA_mapped  19448.969676  2930.996358   310.623940
# reads_per_million_miRNA_mapped  17765.103108  1229.275131  1557.683389
# reads_per_million_miRNA_mapped  14033.836138  1685.285423   559.473572
# reads_per_million_miRNA_mapped  14319.561691  3673.437591   551.830509
# reads_per_million_miRNA_mapped  39564.583597  1091.313855   504.064203
# ...                                      ...          ...          ...
# reads_per_million_miRNA_mapped  11654.395947   505.385792   197.223724
# reads_per_million_miRNA_mapped  51360.209476  3571.319639   483.382939
# reads_per_million_miRNA_mapped  26369.137290  3774.458781   362.068680
# reads_per_million_miRNA_mapped  43200.090804  2095.522759   865.342259
# reads_per_million_miRNA_mapped  11445.440159   867.186092   408.209333
#
# miRNA_ID                         hsa-let-7e  hsa-let-7f-1  hsa-let-7f-2  \
# reads_per_million_miRNA_mapped   563.334943   1192.103985   1270.324057
# reads_per_million_miRNA_mapped  1172.616837   2482.472652   2525.281141
# reads_per_million_miRNA_mapped   851.751649   3134.794583   3236.709070
# reads_per_million_miRNA_mapped  1240.885263   2085.417365   2118.338146
# reads_per_million_miRNA_mapped  1452.774433   1928.119850   1876.624097
# ...                                     ...           ...           ...
# reads_per_million_miRNA_mapped   739.001989    831.744098    791.829772
# reads_per_million_miRNA_mapped   958.658018   2941.223028   3019.212927
# reads_per_million_miRNA_mapped  1001.662085   3536.142847   3680.112627
# reads_per_million_miRNA_mapped   797.599454   4031.597694   4014.301659
# reads_per_million_miRNA_mapped  1288.904354   2336.173186   2363.626816
#
# miRNA_ID                        hsa-let-7g  ...  hsa-mir-942  hsa-mir-943  \
# reads_per_million_miRNA_mapped  559.574362  ...     1.504232     0.000000
# reads_per_million_miRNA_mapped  508.875417  ...    11.331659     0.000000
# reads_per_million_miRNA_mapped  589.836697  ...     4.488462     0.000000
# reads_per_million_miRNA_mapped  499.026881  ...     3.585432     0.000000
# reads_per_million_miRNA_mapped  813.038725  ...     5.941818     0.000000
# ...                                    ...  ...          ...          ...
# reads_per_million_miRNA_mapped  381.533990  ...     1.760926     0.000000
# reads_per_million_miRNA_mapped  551.334535  ...     5.405241     1.544354
# reads_per_million_miRNA_mapped  409.854394  ...     4.288462     0.000000
# reads_per_million_miRNA_mapped  465.191279  ...     2.522338     0.180167
# reads_per_million_miRNA_mapped  575.545744  ...     3.704061     0.217886
#
# miRNA_ID                        hsa-mir-944  hsa-mir-95  hsa-mir-9500  \
# reads_per_million_miRNA_mapped     0.000000    8.273277           0.0
# reads_per_million_miRNA_mapped     0.000000   11.331659           0.0
# reads_per_million_miRNA_mapped     2.376245    0.528054           0.0
# reads_per_million_miRNA_mapped     0.000000    0.977845           0.0
# reads_per_million_miRNA_mapped     0.990303    3.961212           0.0
# ...                                     ...         ...           ...
# reads_per_million_miRNA_mapped     0.000000    2.347901           0.0
# reads_per_million_miRNA_mapped     0.772177    0.772177           0.0
# reads_per_million_miRNA_mapped     1.225275    1.837912           0.0
# reads_per_million_miRNA_mapped     1.261169    2.522338           0.0
# reads_per_million_miRNA_mapped     0.000000    2.832517           0.0
#
# miRNA_ID                        hsa-mir-96  hsa-mir-98  hsa-mir-99a  \
# reads_per_million_miRNA_mapped   25.571947   30.836759   750.611846
# reads_per_million_miRNA_mapped    6.505212  125.907320   242.371590
# reads_per_million_miRNA_mapped   39.868103   60.726249   450.694378
# reads_per_million_miRNA_mapped   64.537768   58.670698  1502.621765
# reads_per_million_miRNA_mapped   43.573330   33.670300   256.488465
# ...                                    ...         ...          ...
# reads_per_million_miRNA_mapped   13.500433   17.022286    96.850936
# reads_per_million_miRNA_mapped   36.678418   42.855836  1198.032956
# reads_per_million_miRNA_mapped   32.469780   55.750000   786.013734
# reads_per_million_miRNA_mapped   27.205222   40.177248   666.618022
# reads_per_million_miRNA_mapped   37.912156   48.806453   295.017580
#
# miRNA_ID                         hsa-mir-99b  \
# reads_per_million_miRNA_mapped  15080.679492
# reads_per_million_miRNA_mapped  48594.979236
# reads_per_million_miRNA_mapped  35905.318801
# reads_per_million_miRNA_mapped  97504.832999
# reads_per_million_miRNA_mapped  85372.037014
# ...                                      ...
# reads_per_million_miRNA_mapped  23230.137194
# reads_per_million_miRNA_mapped  53929.629173
# reads_per_million_miRNA_mapped  39276.793848
# reads_per_million_miRNA_mapped  39819.616767
# reads_per_million_miRNA_mapped  22967.685116
#
# miRNA_ID                                            bcr_patient_uuid
# reads_per_million_miRNA_mapped  51CCBF1B-7CAE-44BA-991A-11EDA8B8C404
# reads_per_million_miRNA_mapped  659B0170-E914-45FF-AA55-FCB8D3DC7B8A
# reads_per_million_miRNA_mapped  78582FBC-DCC7-48AE-9F95-5271C9BC5B72
# reads_per_million_miRNA_mapped  01674B2C-5CF2-478F-84A1-F69C39F47BD4
# reads_per_million_miRNA_mapped  B304302A-F2B9-4CD7-AB14-C21EDF7778EA
# ...                                                              ...
# reads_per_million_miRNA_mapped  B2ECBC0F-2C30-4200-8D5E-7B95424BCADB
# reads_per_million_miRNA_mapped  E666081B-CAAF-4E8B-9446-807BE71201A5
# reads_per_million_miRNA_mapped  AF5453A9-CF1F-40DE-AEC4-0E0710908FB7
# reads_per_million_miRNA_mapped  42378DBC-A123-4CF9-8502-165E89FDA271
# reads_per_million_miRNA_mapped  33FE5833-D7A0-43D7-A03D-56985EA448A6
#
# [1207 rows x 1882 columns]

# %%
# filtering out values beyond 99 percentile and miRNAs that have no data
miRNA_data = miRNA_data.set_index('bcr_patient_uuid')
miRNA_data = pd.DataFrame(miRNA_data)
miRNA_data = miRNA_data[miRNA_data < np.percentile(miRNA_data,99)].dropna(axis = 1)
miRNA_data = miRNA_data.loc[:, (miRNA_data != 0).any(axis=0)]
miRNA_data
# Out:
# miRNA_ID                               hsa-let-7d  hsa-let-7g  hsa-let-7i  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404   310.623940  559.574362  427.954049
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A  1557.683389  508.875417  469.844148
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72   559.473572  589.836697  422.179444
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4   551.830509  499.026881  547.593181
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA   504.064203  813.038725  938.807200
# ...                                           ...         ...         ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB   197.223724  381.533990  241.246877
# E666081B-CAAF-4E8B-9446-807BE71201A5   483.382939  551.334535  490.332534
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7   362.068680  409.854394  512.164834
# 42378DBC-A123-4CF9-8502-165E89FDA271   865.342259  465.191279  499.603182
# 33FE5833-D7A0-43D7-A03D-56985EA448A6   408.209333  575.545744  583.607525
#
# miRNA_ID                              hsa-mir-103b-1  hsa-mir-105-1  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404             0.0       0.000000
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A             0.0     229.780858
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72             0.0       4.752489
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4             0.0       0.651897
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA             0.0       0.000000
# ...                                              ...            ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB             0.0       0.000000
# E666081B-CAAF-4E8B-9446-807BE71201A5             0.0       0.386089
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7             0.0       0.000000
# 42378DBC-A123-4CF9-8502-165E89FDA271             0.0       2.882673
# 33FE5833-D7A0-43D7-A03D-56985EA448A6             0.0       0.000000
#
# miRNA_ID                              hsa-mir-105-2  hsa-mir-106a  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404       0.000000     10.529625
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A     226.633175     28.329147
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72       3.432353      9.504978
# 01674B2C-5CF2-478F-84A1-F69C39F47BD
# 33FE5833-D7A0-43D7-A03D-56985EA448A6   37.912156   48.806453
#
# [1207 rows x 1525 columns]

# %%
# MAD
mad = miRNA_data.mad()
sortedmad = mad.sort_values()
head = sortedmad.head(425)
head = head.index
heads = head.tolist()
miRNA_data = miRNA_data.drop(heads,axis=1)

uids = []
miRNA_data = miRNA_data.reset_index(level=0)
uids = miRNA_data['bcr_patient_uuid']
miRNA_data = miRNA_data.set_index('bcr_patient_uuid')
miRNA_data
# Out:
# miRNA_ID                               hsa-let-7d  hsa-let-7g  hsa-let-7i  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404   310.623940  559.574362  427.954049
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A  1557.683389  508.875417  469.844148
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72   559.473572  589.836697  422.179444
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4   551.830509  499.026881  547.593181
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA   504.064203  813.038725  938.807200
# ...                                           ...         ...         ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB   197.223724  381.533990  241.246877
# E666081B-CAAF-4E8B-9446-807BE71201A5   483.382939  551.334535  490.332534
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7   362.068680  409.854394  512.164834
# 42378DBC-A123-4CF9-8502-165E89FDA271   865.342259  465.191279  499.603182
# 33FE5833-D7A0-43D7-A03D-56985EA448A6   408.209333  575.545744  583.607525
#
# miRNA_ID                              hsa-mir-105-1  hsa-mir-105-2  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404       0.000000       0.000000
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A     229.780858     226.633175
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72       4.752489       3.432353
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4       0.651897       0.977845
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA       0.000000       0.000000
# ...                                             ...            ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB       0.000000       1.173951
# E666081B-CAAF-4E8B-9446-807BE71201A5       0.386089       0.000000
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7       0.000000       0.000000
# 42378DBC-A123-4CF9-8502-165E89FDA271       2.882673       1.621503
# 33FE5833-D7A0-43D7-A03D-56985EA448A6       0.000000       0.000000
#
# miRNA_ID                              hsa-mir-106a  hsa-mir-106b  hsa-mir-107  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404     10.529625    289.564690    23.315598
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A     28.329147   1771.725833   112.267360
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72      9.504978    437.757047    33.267423
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4     21.838538    602.352499    55.085266
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA      5.941818    505.054506   118.836354
# ...                                            ...           ...          ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB      7.630680    321.662502    27.000867
# E666081B-CAAF-4E8B-9446-807BE71201A5     12.740924    648.628864    41.697570
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7      2.450549    490.722526    33.695055
# 42378DBC-A123-4CF9-8502-165E89FDA271     14.773697    485.189819    78.913160
# 33FE5833-D7A0-43D7-A03D-56985EA448A6      3.704061    377.705299   116.677928
#
# miRNA_ID                              hsa-mir-1179  hsa-mir-1180  ...  \
# bcr_patient_uuid                                                  ...
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404      0.000000      7.521161  ...
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A      0.209846     12.590732  ...
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72      0.000000      3.168326  ...
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4      0.000000      0.977845  ...
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA      0.990303      4.951515  ...
# ...                                            ...           ...  ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB      0.000000      2.347901  ...
# E666081B-CAAF-4E8B-9446-807BE71201A5      0.000000      5.019152  ...
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7      0.000000      3.675824  ...
# 42378DBC-A123-4CF9-8502-165E89FDA271      0.180167     12.251358  ...
# 33FE5833-D7A0-43D7-A03D-56985EA448A6      0.000000     17.321933  ...
#
# miRNA_ID                              hsa-mir-937  hsa-mir-938  hsa-mir-939  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404     0.000000          0.0     0.752116
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A    14.269496          0.0     1.259073
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72     2.376245          0.0     0.792082
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4     1.955690          0.0     1.303793
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA     2.970909          0.0     4.951515
# ...                                           ...          ...          ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB     0.586975          0.0     0.586975
# E666081B-CAAF-4E8B-9446-807BE71201A5     2.702620          0.0     0.772177
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7     1.225275          0.0     1.225275
# 42378DBC-A123-4CF9-8502-165E89FDA271     4.504176          0.0     1.441336
# 33FE5833-D7A0-43D7-A03D-56985EA448A6     0.762601          0.0     1.089430
#
# miRNA_ID                              hsa-mir-940  hsa-mir-942  hsa-mir-943  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404     0.752116     1.504232     0.000000
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A     2.098455    11.331659     0.000000
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72     5.016516     4.488462     0.000000
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4    11.082243     3.585432     0.000000
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA     7.922424     5.941818     0.000000
# ...                                           ...          ...          ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB     1.760926     1.760926     0.000000
# E666081B-CAAF-4E8B-9446-807BE71201A5     6.563506     5.405241     1.544354
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7     5.513736     4.288462     0.000000
# 42378DBC-A123-4CF9-8502-165E89FDA271     8.107516     2.522338     0.180167
# 33FE5833-D7A0-43D7-A03D-56985EA448A6     1.634145     3.704061     0.217886
#
# miRNA_ID                              hsa-mir-944  hsa-mir-95  hsa-mir-96  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404     0.000000    8.273277   25.571947
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A     0.000000   11.331659    6.505212
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72     2.376245    0.528054   39.868103
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4     0.000000    0.977845   64.537768
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA     0.990303    3.961212   43.573330
# ...                                           ...         ...         ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB     0.000000    2.347901   13.500433
# E666081B-CAAF-4E8B-9446-807BE71201A5     0.772177    0.772177   36.678418
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7     1.225275    1.837912   32.469780
# 42378DBC-A123-4CF9-8502-165E89FDA271     1.261169    2.522338   27.205222
# 33FE5833-D7A0-43D7-A03D-56985EA448A6     0.000000    2.832517   37.912156
#
# miRNA_ID                              hsa-mir-98
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404   30.836759
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A  125.907320
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72   60.726249
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4   58.670698
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA   33.670300
# ...                                          ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB   17.022286
# E666081B-CAAF-4E8B-9446-807BE71201A5   42.855836
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7   55.750000
# 42378DBC-A123-4CF9-8502-165E89FDA271   40.177248
# 33FE5833-D7A0-43D7-A03D-56985EA448A6   48.806453
#
# [1207 rows x 1100 columns]

# %%
# Z normalization
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()
std_scaler
# fit and transform the data
miRNA_data.std(ddof=0)
miRNA_data = pd.DataFrame(std_scaler.fit_transform(miRNA_data), columns=miRNA_data.columns)
miRNA_data['bcr_patient_uuid'] = uids
miRNA_data = miRNA_data.set_index('bcr_patient_uuid')
miRNA_data
# Out:
# miRNA_ID                              hsa-let-7d  hsa-let-7g  hsa-let-7i  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404   -0.756152   -0.170466   -0.488936
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A    2.696336   -0.323072   -0.316225
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72   -0.067211   -0.079375   -0.512744
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4   -0.088371   -0.352716    0.004331
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA   -0.220612    0.592472    1.617289
# ...                                          ...         ...         ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB   -1.070101   -0.706374   -1.258721
# E666081B-CAAF-4E8B-9446-807BE71201A5   -0.277868   -0.195268   -0.231752
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7   -0.613727   -0.621129   -0.141739
# 42378DBC-A123-4CF9-8502-165E89FDA271    0.779588   -0.454563   -0.193530
# 33FE5833-D7A0-43D7-A03D-56985EA448A6   -0.485986   -0.122391    0.152817
#
# miRNA_ID                              hsa-mir-105-1  hsa-mir-105-2  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404      -0.186764      -0.187714
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A       2.352826       2.302471
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72      -0.134238      -0.150000
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4      -0.179559      -0.176970
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA      -0.186764      -0.187714
# ...                                             ...            ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB      -0.186764      -0.174815
# E666081B-CAAF-4E8B-9446-807BE71201A5      -0.182497      -0.187714
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7      -0.186764      -0.187714
# 42378DBC-A123-4CF9-8502-165E89FDA271      -0.154904      -0.169897
# 33FE5833-D7A0-43D7-A03D-56985EA448A6      -0.186764      -0.187714
#
# miRNA_ID                              hsa-mir-106a  hsa-mir-106b  hsa-mir-107  \
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404     -0.331817     -0.713168    -1.102245
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A      0.099458      2.534523     1.263135
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7    -0.154733   -0.404761   -0.209773
# 42378DBC-A123-4CF9-8502-165E89FDA271    -0.148902   -0.254565   -0.360828
# 33FE5833-D7A0-43D7-A03D-56985EA448A6    -0.353794   -0.186498   -0.053616
#
# miRNA_ID                              hsa-mir-98
# bcr_patient_uuid
# 51CCBF1B-7CAE-44BA-991A-11EDA8B8C404   -0.819522
# 659B0170-E914-45FF-AA55-FCB8D3DC7B8A    1.502853
# 78582FBC-DCC7-48AE-9F95-5271C9BC5B72   -0.089384
# 01674B2C-5CF2-478F-84A1-F69C39F47BD4   -0.139597
# B304302A-F2B9-4CD7-AB14-C21EDF7778EA   -0.750305
# ...                                          ...
# B2ECBC0F-2C30-4200-8D5E-7B95424BCADB   -1.156981
# E666081B-CAAF-4E8B-9446-807BE71201A5   -0.525921
# AF5453A9-CF1F-40DE-AEC4-0E0710908FB7   -0.210944
# 42378DBC-A123-4CF9-8502-165E89FDA271   -0.591353
# 33FE5833-D7A0-43D7-A03D-56985EA448A6   -0.380560
#
# [1207 rows x 1100 columns]

# %%
# molecular subtyping
read = pd.read_csv(r"C:\Users\tanma\Downloads\nationwidechildrens.org_clinical_patient_brca.txt" , sep = "\t")

def subtype(er_status_by_ihc,pr_status_by_ihc,her2_status_by_ihc):
    if er_status_by_ihc == 'Positive' and pr_status_by_ihc == 'Positive' and her2_status_by_ihc == 'Negative':
        return 'Luminal A'
    elif er_status_by_ihc == 'Positive' and pr_status_by_ihc == 'Negative' and her2_status_by_ihc == 'Positive':
        return 'Luminal B'
    elif er_status_by_ihc == 'Negative' and pr_status_by_ihc == 'Negative' and her2_status_by_ihc == 'Positive':
        return 'HER2-Enriched'
    elif er_status_by_ihc == 'Negative' and pr_status_by_ihc == 'Negative' and her2_status_by_ihc == 'Negative':
        return 'Triple-Negative'
    else:
        return 'Unknown'

Subtype = []
for row in read.itertuples(index = True, name ='Pandas'): 
    Subtype.append(subtype(getattr(row, "er_status_by_ihc"), getattr(row, "pr_status_by_ihc"),getattr(row, "her2_status_by_ihc")))

read['Subtype'] = Subtype
selected = read[['bcr_patient_uuid','er_status_by_ihc','pr_status_by_ihc','her2_status_by_ihc','Subtype', 'vital_status', 'last_contact_days_to', 'death_days_to']]
subtype_df = selected.drop([selected.index[0], selected.index[1]]) 


uppercase = []
for case in subtype_df['bcr_patient_uuid']:
    capitalized = case.upper()
    uppercase.append(capitalized)
subtype_df['bcr_patient_uuid'] = uppercase
subtype_df
# Out:
#                           bcr_patient_uuid er_status_by_ihc pr_status_by_ihc  \
# 2     6E7D5EC6-A469-467C-B748-237353C23416         Positive         Positive
# 3     55262FCB-1B01-4480-B322-36570430C917         Positive         Positive
# 4     427D0648-3F77-4FFC-B52C-89855426D647         Positive         Positive
# 5     C31900A4-5DCD-4022-97AC-638E86E889E4         Positive         Positive
# 6     6623FC5E-00BE-4476-967A-CBD55F676EA6         Positive         Positive
# ...                                    ...              ...              ...
# 1094  5CD79093-1571-4F71-8136-0D84CCABDCAC         Positive         Positive
# 1095  F89588E9-CA73-4465-A7FB-7246EDB45E3A         Positive         Positive
# 1096  CA20249F-B7EA-4FD9-9ECB-34F74755AE35         Positive         Positive
# 1097  23F438BD-1DBB-4D46-972F-1E8E74DDBD37         Positive         Positive
# 1098  B1D44C81-747D-471F-9093-AEB262A17975         Positive         Positive
#
#      her2_status_by_ihc    Subtype vital_status last_contact_days_to  \
# 2              Negative  Luminal A        Alive                 3767
# 3              Positive    Unknown        Alive                 3801
# 4         Indeterminate    Unknown        Alive                 1228
# 5              Positive    Unknown        Alive                 1217
# 6             Equivocal    Unknown        Alive                  158
# ...                 ...        ...          ...                  ...
# 1094           Negative  Luminal A        Alive                  791
# 1095           Negative  Luminal A        Alive                  292
# 1096           Negative  Luminal A        Alive                  278
# 1097           Negative  Luminal A        Alive                 3042
# 1098           Negative  Luminal A        Alive                 2800
#
#          death_days_to
# 2     [Not Applicable]
# 3     [Not Applicable]
# 4     [Not Applicable]
# 5     [Not Applicable]
# 6     [Not Applicable]
# ...                ...
# 1094  [Not Applicable]
# 1095  [Not Applicable]
# 1096  [Not Applicable]
# 1097  [Not Applicable]
# 1098  [Not Applicable]
#
# [1097 rows x 8 columns]

# %%
# clustering

miRNA_data = miRNA_data.reset_index(level=0)
miRNA_data = miRNA_data.drop(miRNA_data[ miRNA_data['bcr_patient_uuid'] == '05135396-DF5C-49DB-B34E-F4ADD5B65A2B' ].index)
miRNA_data = miRNA_data.drop(miRNA_data[ miRNA_data['bcr_patient_uuid'] == '6A186809-3422-41D0-83D2-867145830936' ].index)
miRNA_data = miRNA_data.drop(miRNA_data[ miRNA_data['bcr_patient_uuid'] == '6E126B73-D3E8-4641-A128-306F3B313E40' ].index)
miRNA_data = miRNA_data.set_index('bcr_patient_uuid')


from sklearn.cluster import AgglomerativeClustering
cluster = AgglomerativeClustering(n_clusters = 4, affinity = 'euclidean', linkage = 'ward')  
clusterdata = cluster.fit_predict(miRNA_data)
miRNA_data['cluster'] = clusterdata
miRNA_data = miRNA_data.reset_index(level=0)
merged_miRNA_df = pd.merge(subtype_df, miRNA_data, on = 'bcr_patient_uuid', how = 'left')


miRNA_grouped_data = merged_miRNA_df[['Subtype','cluster']]
miRNA_grouped_data = miRNA_grouped_data.groupby(['cluster','Subtype'])
count = miRNA_grouped_data.size()
miRNA_grouped_data = count.to_frame()
miRNA_grouped_data.columns = ['count']
miRNA_grouped_data = miRNA_grouped_data.reset_index()
miRNA_grouped_data = miRNA_grouped_data.pivot_table(columns = "Subtype" , values = "count",index = 'cluster').fillna(0)
miRNA_grouped_data
# Out:
# Subtype  HER2-Enriched  Luminal A  Luminal B  Triple-Negative  Unknown
# cluster
# 0.0                  3         47          5               11       53
# 1.0                 11         88          3               30      127
# 2.0                 25        266         13               78      403
# 3.0                  2          7          2                5       23

# %%
# chi squared test for cluster and subtype

from scipy.stats import chi2_contingency
import pandas as pd
import numpy as np

miRNA_grouped_data = miRNA_grouped_data.drop(columns = "Unknown")

chi2_contingency(miRNA_grouped_data)
df_1 = chi2_contingency(miRNA_grouped_data)[3]

pd.DataFrame(
    data=df_1[:,:], 
    index=miRNA_grouped_data.index,
    columns=miRNA_grouped_data.columns
).round(2)

chisquare=chi2_contingency(miRNA_grouped_data)[0]

pvalue=chi2_contingency(miRNA_grouped_data)[1]

dof=chi2_contingency(miRNA_grouped_data)[2]

from scipy.stats import chi2
significance = 0.01
p = 1 - significance
dof = chi2_contingency(miRNA_grouped_data)[2]
critical_value = chi2.ppf(p, dof)

p = chi2.cdf(critical_value, dof)

chi, pval, dof, exp = chi2_contingency(miRNA_grouped_data)
print('p-value is: ', pval)
significance = 0.05
p = 1 - significance
critical_value = chi2.ppf(p, dof)
print('chi=%.6f, critical value=%.6f\n' % (chi, critical_value))
if chi > critical_value:
    print("""At %.2f level of significance, we reject the null hypotheses and accept H1. 
They are not independent.""" % (significance))
else:
    print("""At %.2f level of significance, we accept the null hypotheses. 
They are independent.""" % (significance))
    

chi, pval, dof, exp = chi2_contingency(miRNA_grouped_data)
significance = 0.05
print('p-value=%.6f, significance=%.2f\n' % (pval, significance))
if pval < significance:
    print("""At %.2f level of significance, we reject the null hypotheses and accept H1. 
They are not independent.""" % (significance))
else:
    print("""At %.2f level of significance, we accept the null hypotheses. 
They are independent.""" % (significance))
# Out:
# p-value is:  0.24092764088080124
# chi=11.533107, critical value=16.918978
#
# At 0.05 level of significance, we accept the null hypotheses.
# They are independent.
# p-value=0.240928, significance=0.05
#
# At 0.05 level of significance, we accept the null hypotheses.
# They are independent.

# %%
# Kaplan Meier

merged_miRNA_df = merged_miRNA_df.replace('Dead', '1')
merged_miRNA_df = merged_miRNA_df.replace('Alive', '0')
merged_miRNA_df = merged_miRNA_df.replace('[Not Available]', '')
merged_miRNA_df = merged_miRNA_df.replace('[Not Applicable]', '')
merged_miRNA_df = merged_miRNA_df.fillna(0)
merged_miRNA_df['duration'] = merged_miRNA_df['last_contact_days_to'] + merged_miRNA_df['death_days_to']


selected_miRNA_df = merged_miRNA_df[['bcr_patient_uuid','er_status_by_ihc','pr_status_by_ihc','her2_status_by_ihc','Subtype','vital_status','last_contact_days_to','death_days_to','duration','cluster']]
selected_miRNA_df_clustered = selected_miRNA_df.groupby('cluster')

from lifelines import KaplanMeierFitter

selected_miRNA_df_clustered.get_group(0)

for x in set(merged_miRNA_df['cluster'].tolist()):
    kmf = KaplanMeierFitter()
    kmf.fit(durations = selected_miRNA_df_clustered.get_group(x)['duration'], event_observed = selected_miRNA_df_clustered.get_group(x)['vital_status'],label='Kaplan Meier Estimate cluster: ' + str(x))
    kmf.plot(ci_show=False)
# Out:
# C:\Users\tanma\AppData\Roaming\Python\Python39\site-packages\lifelines\utils\__init__.py:1175: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# C:\Users\tanma\AppData\Roaming\Python\Python39\site-packages\lifelines\utils\__init__.py:1175: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# C:\Users\tanma\AppData\Roaming\Python\Python39\site-packages\lifelines\utils\__init__.py:1175: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)
# C:\Users\tanma\AppData\Roaming\Python\Python39\site-packages\lifelines\utils\__init__.py:1175: UserWarning: Attempting to convert an unexpected datatype 'object' to float. Suggestion: 1) use `lifelines.utils.datetimes_to_durations` to do conversions or 2) manually convert to floats/booleans.
#   warnings.warn(warning_text, UserWarning)

# %%
from lifelines.statistics import logrank_test
from itertools import combinations

comb = combinations(set(merged_miRNA_df['cluster'].tolist()),2)

for i in comb:
    print(i)
    results = logrank_test(selected_miRNA_df_clustered.get_group(i[0])['duration'].astype(int), selected_miRNA_df_clustered.get_group(i[1])['duration'].astype(int), selected_miRNA_df_clustered.get_group(i[0])['vital_status'].astype(int), selected_miRNA_df_clustered.get_group(i[1])['vital_status'].astype(int), alpha=.05)
    print(results)
# Out:
# (0.0, 1.0)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              alpha = 0.05
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.88 0.35      1.52
# (0.0, 2.0)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              alpha = 0.05
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.02 0.89      0.16
# (0.0, 3.0)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              alpha = 0.05
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            0.62 0.43      1.21
# (1.0, 2.0)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              alpha = 0.05
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.88 0.17      2.55
# (1.0, 3.0)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              alpha = 0.05
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            2.19 0.14      2.85
# (2.0, 3.0)
# <lifelines.StatisticalResult: logrank_test>
#                t_0 = -1
#  null_distribution = chi squared
# degrees_of_freedom = 1
#              alpha = 0.05
#          test_name = logrank_test
#
# ---
#  test_statistic    p  -log2(p)
#            1.20 0.27      1.87
